# %%
library(readxl)
library(tidyverse)
library(dplyr)
library(ggplot2)

url <- "https://archive.ics.uci.edu/ml/machine-learning-databases/00547/Algerian_forest_fires_dataset_UPDATE.csv"

# %%
download.file(url, destfile = "data/Algerian_forest_fires_dataset_UPDATE.csv")

# %%
Bejaia_basic <- read_csv(file = "data/Algerian_forest_fires_dataset_UPDATE.csv", skip=1, n_max=122)
print(Bejaia_basic, n = 10)
# Bejaia_basic
SidiBelAbbes_basic <- read_csv(file = "data/Algerian_forest_fires_dataset_UPDATE.csv", skip=126)
# SidiBelAbbes_basic
print( SidiBelAbbes_basic, n = 10)
# Out:
# Parsed with column specification:
# cols(
#   day = col_character(),
#   month = col_character(),
#   year = col_double(),
#   Temperature = col_double(),
#   RH = col_double(),
#   Ws = col_double(),
#   Rain = col_double(),
#   FFMC = col_double(),
#   DMC = col_double(),
#   DC = col_double(),
#   ISI = col_double(),
#   BUI = col_double(),
#   FWI = col_double(),
#   Classes = col_character()
# )
# # A tibble: 122 x 14
#    day   month  year Temperature    RH    Ws  Rain  FFMC   DMC    DC   ISI   BUI
#    <chr> <chr> <dbl>       <dbl> <dbl> <dbl> <dbl> <dbl> <dbl> <dbl> <dbl> <dbl>
#  1 01    06     2012          29    57    18   0    65.7   3.4   7.6   1.3   3.4
#  2 02    06     2012          29    61    13   1.3  64.4   4.1   7.6   1     3.9
#  3 03    06     2012          26    82    22  13.1  47.1   2.5   7.1   0.3   2.7
#  4 04    06     2012          25    89    13   2.5  28.6   1.3   6.9   0     1.7
#  5 05    06     2012          27    77    16   0    64.8   3    14.2   1.2   3.9
#  6 06    06     2012          31    67    14   0    82.6   5.8  22.2   3.1   7
#  7 07    06     2012          33    54    13   0    88.2   9.9  30.5   6.4  10.9
#  8 08    06     2012          30    73    15   0    86.6  12.1  38.3   5.6  13.5
#  9 09    06     2012          25    88    13   0.2  52.9   7.9  38.8   0.4  10.5
# 10 10    06     2012          28    79    12   0    73.2   9.5  46.3   1.3  12.6
# # … with 112 more rows, and 2 more variables: FWI <dbl>, Classes <chr>
# Parsed with column specification:
# cols(
#   day = col_character(),
#   month = col_character(),
#   year = col_double(),
#   Temperature = col_double(),
#   RH = col_double(),
#   Ws = col_double(),
#   Rain = col_double(),
#   FFMC = col_double(),
#   DMC = col_double(),
#   DC = col_character(),
#   ISI = col_double(),
#   BUI = col_double(),
#   FWI = col_character(),
#   Classes = col_character()
# )
#
# Warning message:
# “1 parsing failure.
# row col   expected     actual                                            file
#  44  -- 14 columns 13 columns 'data/Algerian_forest_fires_dataset_UPDATE.csv'
# ”
# # A tibble: 122 x 14
#    day   month  year Temperature    RH    Ws  Rain  FFMC   DMC DC      ISI   BUI
#    <chr> <chr> <dbl>       <dbl> <dbl> <dbl> <dbl> <dbl> <dbl> <chr> <dbl> <dbl>
#  1 01    06     2012          32    71    12   0.7  57.1   2.5 8.2     0.6   2.8
#  2 02    06     2012          30    73    13   4    55.7   2.7 7.8     0.6   2.9
#  3 03    06     2012          29    80    14   2    48.7   2.2 7.6     0.3   2.6
#  4 04    06     2012          30    64    14   0    79.4   5.2 15.4    2.2   5.6
#  5 05    06     2012          32    60    14   0.2  77.1   6   17.6    1.8   6.5
#  6 06    06     2012          35    54    11   0.1  83.7   8.4 26.3    3.1   9.3
#  7 07    06     2012          35    44    17   0.2  85.6   9.9 28.9    5.4  10.7
#  8 08    06     2012          28    51    17   1.3  71.4   7.7 7.4     1.5   7.3
#  9 09    06     2012          27    59    18   0.1  78.1   8.5 14.7    2.4   8.3
# 10 10    06     2012          30    41    15   0    89.4  13.3 22.5    8.4  13.1
# # … with 112 more rows, and 2 more variables: FWI <chr>, Classes <chr>

# %%
# change type of day and month
Bejaia_basic$day <- as.double(Bejaia_basic$day)
Bejaia_basic$month <- as.double(Bejaia_basic$month)
Bejaia_basic<-mutate(Bejaia_basic, date = month*30 + day)
# add a date column to data

#FWI with color of fire
FWI_time_range <- ggplot(data=Bejaia_basic, aes (x=date, y=FWI)) +
geom_point(aes(colour = Classes)) + 
labs(x = "month", y = "FWI with fire", colour = "Colours") +
theme(text =  element_text(size=20))
FWI_time_range
#怎么表现date
# Out:
# plot without title

# %%
FWI_time_range <- ggplot(data=Bejaia_basic, aes (x=day, y=Temperature)) +
geom_line(aes(colour = month)) + 
labs(x = "day", y = "FWI with fire", colour = "Colours",shape = "Shapes") +
theme(text =  element_text(size=20))
FWI_time_range
#为啥会有垂直线
# Out:
# plot without title

# %%
each_month <- Bejaia_basic %>%
group_by(Classes, month) %>%
   summarize(n=n()) 
each_month 
top_n_state_plot <- ggplot(each_month, aes(x = month, y =n, fill = Classes)) + 
   geom_bar(stat = "identity", position = "fill") + 
  xlab("US State") +
  ylab("number") +
  labs(fill = "Restaurant") 
 
# NEED TO CHANGE LABLE
top_n_state_plot
# Out:
# `summarise()` regrouping output by 'Classes' (override with `.groups` argument)
#   Classes  month n
# 1 fire     6     13
# 2 fire     7     15
# 3 fire     8     24
# 4 fire     9      7
# 5 not fire 6     17
# 6 not fire 7     16
# 7 not fire 8      7
# 8 not fire 9     23
# plot without title
