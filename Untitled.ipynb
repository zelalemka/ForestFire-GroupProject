# %%
library(readxl)
library(tidyverse)
library(dplyr)
library(ggplot2)
url <- "https://archive.ics.uci.edu/ml/machine-learning-databases/00547/Algerian_forest_fires_dataset_UPDATE.csv"

# %%
download.file(url, destfile = "data/Algerian_forest_fires_dataset_UPDATE.csv")

# %%
Bejaia_basic <- read_csv(file = "data/Algerian_forest_fires_dataset_UPDATE.csv", skip=1, n_max=122)
print(Bejaia_basic, n = 10)
# Bejaia_basic
SidiBelAbbes_basic <- read_csv(file = "data/Algerian_forest_fires_dataset_UPDATE.csv", skip=126)
# SidiBelAbbes_basic
print( SidiBelAbbes_basic, n = 10)
# Out:
# Parsed with column specification:
# cols(
#   day = col_character(),
#   month = col_character(),
#   year = col_double(),
#   Temperature = col_double(),
#   RH = col_double(),
#   Ws = col_double(),
#   Rain = col_double(),
#   FFMC = col_double(),
#   DMC = col_double(),
#   DC = col_double(),
#   ISI = col_double(),
#   BUI = col_double(),
#   FWI = col_double(),
#   Classes = col_character()
# )
# # A tibble: 122 x 14
#    day   month  year Temperature    RH    Ws  Rain  FFMC   DMC    DC   ISI   BUI
#    <chr> <chr> <dbl>       <dbl> <dbl> <dbl> <dbl> <dbl> <dbl> <dbl> <dbl> <dbl>
#  1 01    06     2012          29    57    18   0    65.7   3.4   7.6   1.3   3.4
#  2 02    06     2012          29    61    13   1.3  64.4   4.1   7.6   1     3.9
#  3 03    06     2012          26    82    22  13.1  47.1   2.5   7.1   0.3   2.7
#  4 04    06     2012          25    89    13   2.5  28.6   1.3   6.9   0     1.7
#  5 05    06     2012          27    77    16   0    64.8   3    14.2   1.2   3.9
#  6 06    06     2012          31    67    14   0    82.6   5.8  22.2   3.1   7
#  7 07    06     2012          33    54    13   0    88.2   9.9  30.5   6.4  10.9
#  8 08    06     2012          30    73    15   0    86.6  12.1  38.3   5.6  13.5
#  9 09    06     2012          25    88    13   0.2  52.9   7.9  38.8   0.4  10.5
# 10 10    06     2012          28    79    12   0    73.2   9.5  46.3   1.3  12.6
# # … with 112 more rows, and 2 more variables: FWI <dbl>, Classes <chr>
# Parsed with column specification:
# cols(
#   day = col_character(),
#   month = col_character(),
#   year = col_double(),
#   Temperature = col_double(),
#   RH = col_double(),
#   Ws = col_double(),
#   Rain = col_double(),
#   FFMC = col_double(),
#   DMC = col_double(),
#   DC = col_character(),
#   ISI = col_double(),
#   BUI = col_double(),
#   FWI = col_character(),
#   Classes = col_character()
# )
#
# Warning message:
# “1 parsing failure.
# row col   expected     actual                                            file
#  44  -- 14 columns 13 columns 'data/Algerian_forest_fires_dataset_UPDATE.csv'
# ”
# # A tibble: 122 x 14
#    day   month  year Temperature    RH    Ws  Rain  FFMC   DMC DC      ISI   BUI
#    <chr> <chr> <dbl>       <dbl> <dbl> <dbl> <dbl> <dbl> <dbl> <chr> <dbl> <dbl>
#  1 01    06     2012          32    71    12   0.7  57.1   2.5 8.2     0.6   2.8
#  2 02    06     2012          30    73    13   4    55.7   2.7 7.8     0.6   2.9
#  3 03    06     2012          29    80    14   2    48.7   2.2 7.6     0.3   2.6
#  4 04    06     2012          30    64    14   0    79.4   5.2 15.4    2.2   5.6
#  5 05    06     2012          32    60    14   0.2  77.1   6   17.6    1.8   6.5
#  6 06    06     2012          35    54    11   0.1  83.7   8.4 26.3    3.1   9.3
#  7 07    06     2012          35    44    17   0.2  85.6   9.9 28.9    5.4  10.7
#  8 08    06     2012          28    51    17   1.3  71.4   7.7 7.4     1.5   7.3
#  9 09    06     2012          27    59    18   0.1  78.1   8.5 14.7    2.4   8.3
# 10 10    06     2012          30    41    15   0    89.4  13.3 22.5    8.4  13.1
# # … with 112 more rows, and 2 more variables: FWI <chr>, Classes <chr>

# %%
# change type of day and month
# add a date column to data
Bejaia_basic$year <- as.character(Bejaia_basic$year)

Bejaia_with_date<-tidyr::unite(Bejaia_basic, "date", year, month,day, remove = FALSE,sep = "-" )
Bejaia_with_date

#FWI with color of fire
FWI_time_range <- ggplot(data=Bejaia_with_date, aes (x=date, y=FWI)) +
geom_point(aes(colour = Classes)) + 
labs(x = "month", y = "FWI with fire", colour = "Colours") +
theme(text =  element_text(size=20))
FWI_time_range
#怎么表现date
# Out:
#     date       day month year Temperature RH Ws Rain FFMC DMC  DC   ISI BUI
# 1   2012-06-01 01  06    2012 29          57 18  0.0 65.7  3.4  7.6 1.3  3.4
# 2   2012-06-02 02  06    2012 29          61 13  1.3 64.4  4.1  7.6 1.0  3.9
# 3   2012-06-03 03  06    2012 26          82 22 13.1 47.1  2.5  7.1 0.3  2.7
# 4   2012-06-04 04  06    2012 25          89 13  2.5 28.6  1.3  6.9 0.0  1.7
# 5   2012-06-05 05  06    2012 27          77 16  0.0 64.8  3.0 14.2 1.2  3.9
# 6   2012-06-06 06  06    2012 31          67 14  0.0 82.6  5.8 22.2 3.1  7.0
# 7   2012-06-07 07  06    2012 33          54 13  0.0 88.2  9.9 30.5 6.4 10.9
# 8   2012-06-08 08  06    2012 30          73 15  0.0 86.6 12.1 38.3 5.6 13.5
# 9   2012-06-09 09  06    2012 25          88 13  0.2 52.9  7.9 38.8 0.4 10.5
# 10  2012-06-10 10  06    2012 28          79 12  0.0 73.2  9.5 46.3 1.3 12.6
# 11  2012-06-11 11  06    2012 31          65 14  0.0 84.5 12.5 54.3 4.0 15.8
# 12  2012-06-12 12  06    2012 26          81 19  0.0 84.0 13.8 61.4 4.8 17.7
# 13  2012-06-13 13  06    2012 27          84 21  1.2 50.0  6.7 17.0 0.5  6.7
# 14  2012-06-14 14  06    2012 30          78 20  0.5 59.0  4.6  7.8 1.0  4.4
# 15  2012-06-15 15  06    2012 28          80 17  3.1 49.4  3.0  7.4 0.4  3.0
# 16  2012-06-16 16  06    2012 29          89 13  0.7 36.1  1.7  7.6 0.0  2.2
# 17  2012-06-17 17  06    2012 30          89 16  0.6 37.3  1.1  7.8 0.0  1.6
# 18  2012-06-18 18  06    2012 31          78 14  0.3 56.9  1.9  8.0 0.7  2.4
# 19  2012-06-19 19  06    2012 31          55 16  0.1 79.9  4.5 16.0 2.5  5.3
# 20  2012-06-20 20  06    2012 30          80 16  0.4 59.8  3.4 27.1 0.9  5.1
# 21  2012-06-21 21  06    2012 30          78 14  0.0 81.0  6.3 31.6 2.6  8.4
# 115 2012-09-23 23  09    2012 32          54 11  0.5 73.7  7.9 30.4 1.2  9.6
# 116 2012-09-24 24  09    2012 29          65 19  0.6 68.3  5.5 15.2 1.5  5.8
# 117 2012-09-25 25  09    2012 26          81 21  5.8 48.6  3.0  7.7 0.4  3.0
# 118 2012-09-26 26  09    2012 31          54 11  0.0 82.0  6.0 16.3 2.5  6.2
# 119 2012-09-27 27  09    2012 31          66 11  0.0 85.7  8.3 24.9 4.0  9.0
# 120 2012-09-28 28  09    2012 32          47 14  0.7 77.5  7.1  8.8 1.8  6.8
# 121 2012-09-29 29  09    2012 26          80 16  1.8 47.4  2.9  7.7 0.3  3.0
# 122 2012-09-30 30  09    2012 25          78 14  1.4 45.0  1.9  7.5 0.2  2.4
#     FWI  Classes
# 1    0.5 not fire
# 2    0.4 not fire
# 3    0.1 not fire
# 4    0.0 not fire
# 5    0.5 not fire
# 6    2.5 fire
# 7    7.2 fire
# 8    7.1 fire
# 9    0.3 not fire
# 10   0.9 not fire
# 11   5.6 fire
# 12   7.1 fire
# 13   0.2 not fire
# 14   0.4 not fire
# 15   0.1 not fire
# 16   0.0 not fire
# 17   0.0 not fire
# 18   0.2 not fire
# 19   1.4 not fire
# 20   0.4 not fire
# 21   2.2 fire
# 22   2.3 not fire
# 23   3.8 fire
# 24   7.5 fire
# 25   8.4 fire
# 26  10.6 fire
# 27  15.0 fire
# 28  13.9 fire
# 29   3.9 not fire
# 30  12.9 fire
# ⋮   ⋮    ⋮
# 93  0.1  not fire
# 94  0.0  not fire
# 95  0.0  not fire
# 96  0.5  not fire
# 97  1.7  fire
# 98  0.9  not fire
# 99  0.6  not fire
# 100 0.4  not fire
# 101 0.2  not fire
# 102 0.3  not fire
# 103 0.3  not fire
# 104 0.5  not fire
# 105 0.0  not fire
# 106 0.1  not fire
# 107 0.0  not fire
# 108 0.8  not fire
# 109 5.9  fire
# 110 7.7  fire
# 111 9.7  fire
# 112 6.3  fire
# 113 8.3  fire
# 114 2.8  not fire
# 115 0.7  not fire
# 116 0.7  not fire
# 117 0.1  not fire
# 118 1.7  not fire
# 119 4.1  fire
# 120 0.9  not fire
# 121 0.1  not fire
# 122 0.1  not fire
# plot without title

# %%
FWI_time_range <- ggplot(data=Bejaia_basic, aes (x=day, y=Temperature)) +
geom_line(aes(colour = month)) + 
labs(x = "day", y = "FWI with fire", colour = "Colours",shape = "Shapes") +
theme(text =  element_text(size=20))
FWI_time_range
#为啥会有垂直线
# Out:
# plot without title

# %%
each_month <- Bejaia_basic %>%
group_by(Classes, month) %>%
   summarize(n=n()) 
each_month 
top_n_state_plot <- ggplot(each_month, aes(x = month, y =n, fill = Classes)) + 
   geom_bar(stat = "identity", position = "fill") + 
  xlab("US State") +
  ylab("number") +
  labs(fill = "Restaurant") 
# NEED TO CHANGE LABLE
top_n_state_plot
# Out:
# `summarise()` regrouping output by 'Classes' (override with `.groups` argument)
#   Classes  month n
# 1 fire     6     13
# 2 fire     7     15
# 3 fire     8     24
# 4 fire     9      7
# 5 not fire 6     17
# 6 not fire 7     16
# 7 not fire 8      7
# 8 not fire 9     23
# plot without title
